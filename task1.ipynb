# %%
# User Login Check
username = "admin"
password = "1234"

user=input("Enter username: ")
pwd=input("Enter password: ")

if user== username and pwd==password:
  print("Login Sucessful")
else:
  print("Invalid Credentials")
# Out:
# Enter username: admin
# Enter password: 1234
# Login Sucessful

# %%
# Pass / Fail Analyzer
marks=[45,78,90,33,60]

pass_count=0
fail_count=0
for mark in marks:
  if mark>=50:
    pass_count+=1
  else:
    fail_count+=1
print("Passed Students:",pass_count)
print("Failed Students:",fail_count)
# Out:
# Passed Students: 3
# Failed Students: 2

# %%
# Simple Data Cleaner
names = [" Alice ", "bob", " CHARLIE "]

cleaned_names=[]
for name in names:
  clean=name.strip().lower()
  cleaned_names.append(clean)
print("cleaned_list:",cleaned_names)
# Out:
# cleaned_list: ['alice', 'bob', 'charlie']

# %%
# Message Length Analyzer
messages = ["Hi", "Welcome to the platform", "OK"]
for msg in messages:
  length=len(msg)
  print("Message:",msg)
  print("Length:",length)

  if length>10:
    print("Message is too long")
  else:
    print("Message is too short")

  print()
# Out:
# Message: Hi
# Length: 2
# Message is too short
#
# Message: Welcome to the platform
# Length: 23
# Message is too long
#
# Message: OK
# Length: 2
# Message is too short

# %%
# Error Message Detector
logs = ["INFO", "ERROR", "WARNING", "ERROR"]
error_count=0
for log in logs:
  if log=="ERROR":
    error_count+=1
print("Total Error Count:",error_count)
# Out:
# Total Error Count: 2
